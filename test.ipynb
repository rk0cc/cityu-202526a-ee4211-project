# %% [markdown]
# # Test run Jupyter Notebook file
#
# This file aims for verifies Jupyter Notebook can be executed normally in IDE.
#
# **DO NOT** submit this file to Canvas.

# %%
import numpy as np
import platform

# %%
print("Hello World")
# Out:
# Hello World

# %%
np.matrix([[1, 2, 3], [4, 5, 6]]) * np.matrix([[3, 4], [7, 8], [9, 0]])
# Out:
# matrix([[ 44,  20],
#         [101,  56]])

# %%
platform.uname()
# Out:
# uname_result(system='Linux', node='raspberrypi', release='6.12.53-v8+', version='#1913 SMP PREEMPT Fri Oct 17 19:58:42 BST 2025', machine='aarch64')
